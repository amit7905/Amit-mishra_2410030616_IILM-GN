# %%
print("the sum 1 to 5 is  :", 1+2+3+4+5)
# Out:
# the sum 1 to 5 is  : 15

# %%
S = 0

for N in range(1, 100, 2):
    S += N

print(S)
# Out:
# 2500

# %%
print("Enter an integer:")
n = int(input())

if n % 2 == 0:
    print("n is even")
else:
    print("n is odd")
# Out:
# Enter an integer:
#  5
# n is odd

# %%
# number of symbols (you can change n)
n = 30

# First line → continuous stars
print('*' * n)

# Second line → # with spaces
print('# ' * n)
# Out:
# ******************************
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #

# %%
# Store name and address in variables
name = "David Doe"
address = "1600 Wilshire Blvd #205, Los Angeles CA 90017"

# Print them
print(name)
print(address)
# Out:
# David Doe
# 1600 Wilshire Blvd #205, Los Angeles CA 90017

# %%
x = 1
y = 0

print(x and y)
print(x or y)
print(not x)
print(not y)
# Out:
# 0
# 1
# False
# True

# %%
num1 = int(input("Enter first integer: "))
num2 = int(input("Enter second integer: "))

if num1 < num2:
    print("Numbers in ascending order:", num1, num2)
else:
    print("Numbers in ascending order:", num2, num1)
# Out:
# Enter first integer:  56
# Enter second integer:  45
# Numbers in ascending order: 45 56

# %%
# Take inputs
adult = int(input("Are you an adult? (1 if you are an adult, 0 if you are minor): "))
married = int(input("Are you married? (1 if you are married, 0 if you are single): "))

# Compound conditional statements
if adult == 1 and married == 1:
    print("You are an adult who is married.")

elif adult == 1 and married == 0:
    print("You are an adult who is single.")

elif adult == 0 and married == 1:
    print("You are a minor who is married.")

else:
    print("You are a minor who is single.")
# Out:
# Are you an adult? (1 if you are an adult, 0 if you are minor):  1
# Are you married? (1 if you are married, 0 if you are single):  0
# You are an adult who is single.

# %%
# Loop from 2 to 12
for num in range(2, 13):
    
    # Assume number is prime
    is_prime = True
    
    # Inner loop to check divisibility
    for i in range(2, num):
        if num % i == 0:
            is_prime = False
            break
    
    # Print result
    if is_prime:
        print(num, ": Prime number")
    else:
        print(num, ": Composite number")
# Out:
# 2 : Prime number
# 3 : Prime number
# 4 : Composite number
# 5 : Prime number
# 6 : Composite number
# 7 : Prime number
# 8 : Composite number
# 9 : Composite number
# 10 : Composite number
# 11 : Prime number
# 12 : Composite number

# %%
for num in range(100, 1000):
    digits = [int(d) for d in str(num)]
    if sum(d**3 for d in digits) == num:
        print(num, end=" ")
# Out:
# 153 370 371 407

# %%
l1 = ['I like', 'I love']
l2 = ['pancake.', 'kiwi juice.', 'espresso.']

for x in l1:
    for y in l2:
        print(x, y)
# Out:
# I like pancake.
# I like kiwi juice.
# I like espresso.
# I love pancake.
# I love kiwi juice.
# I love espresso.

# %%
person = {'Name': 'David Doe', 'Age': 26, 'Weight': 82, 'Job': 'Data scientist'}

person['Father'] = 'John Doe'

print(person)
# Out:
# {'Name': 'David Doe', 'Age': 26, 'Weight': 82, 'Job': 'Data scientist', 'Father': 'John Doe'}

# %%
st = [5, 6, 3, 9, 2, 12, 3, 8, 7]

max_index = 0
for i in range(1, len(lst)):
    if lst[i] > lst[max_index]:
        max_index = i

# Swap largest element with the last element
lst[max_index], lst[-1] = lst[-1], lst[max_index]

print(lst)
# Out:
# [5, 6, 3, 9, 2, 7, 3, 8, 12]

# %%
maria = {'korean': 94, 'english': 91, 'mathematics': 89, 'science': 83}

average = sum(maria.values()) / len(maria)

print("Average score:", average)
# Out:
# Average score: 89.25

# %%
import copy

school = {
    'kim': {'age': 16, 'hei': 170, 'grade': 3},
    'lee': {'age': 15, 'hei': 168, 'grade': 2},
    'choi': {'age': 14, 'hei': 173, 'grade': 1}
}

school2 = copy.deepcopy(school)

print("school is school2:", school is school2)
# Out:
# school is school2: False

# %%
scores = (
    ('Hyun', 88, 95, 90),
    ('Kang', 85, 90, 95),
    ('Park', 70, 90, 80),
    ('Hong', 90, 90, 95)
)

# Unpack with zip: names, english, math, science
names, english, math, science = zip(*scores)

average_math = sum(math) / len(math)

print("Average math score:", average_math)
# Out:
# Average math score: 91.25
